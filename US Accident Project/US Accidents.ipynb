# %% [markdown]
# # US Accidents Exploratory Data Analysis

# %% [raw]
# TODO- talk about EDA
# .Kaggle
# .information about accidents
# .can use useful to prevent accidents
# .this data is not contain data for New York

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Upload the dataset

# %%
df= pd.read_csv("C:\\Users\\user\\Desktop\\New folder\\US Accident Project\\US_Accidents_Dec20_updated.csv")

# %% [markdown]
# # Data Preparation and Cleaning

# %% [raw]
# 1.look at some imformation about the data & the columns
# 2.Fix any missing or incorrect values

# %%
df
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0        A-2716600         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1        A-2716601         2  2016-02-08 05:56:20  2016-02-08 11:56:20
# 2        A-2716602         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 3        A-2716603         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 4        A-2716604         2  2016-02-08 06:51:45  2016-02-08 12:51:45
# ...            ...       ...                  ...                  ...
# 1516059  A-4239402         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 1516060  A-4239403         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 1516061  A-4239404         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 1516062  A-4239405         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 1516063  A-4239406         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat  Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 47

# %%
len(df)
# Out:
# 1516064

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516064 entries, 0 to 1516063
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1516064 non-null  object
#  1   Severity               1516064 non-null  int64
#  2   Start_Time             1516064 non-null  object
#  3   End_Time               1516064 non-null  object
#  4   Start_Lat              1516064 non-null  float64
#  5   Start_Lng              1516064 non-null  float64
#  6   End_Lat                1516064 non-null  float64
#  7   End_Lng                1516064 non-null  float64
#  8   Distance(mi)           1516064 non-null  float64
#  9   Description            1516064 non-null  object
#  10  Number                 469969 non-null   float64
#  11  Street                 1516064 non-null  object
#  12  Side                   1516064 non-null  object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  1.516064e+06  1.516064e+06  1.516064e+06  1.516064e+06  1.516064e+06
# mean   2.238630e+00  3.690056e+01 -9.859919e+01  3.690061e+01 -9.859901e+01
# std    6.081481e-01  5.165653e+00  1.849602e+01  5.165629e+00  1.849590e+01
# min    1.000000e+00  2.457022e+01 -1.244976e+02  2.457011e+01 -1.244978e+02
# 25%    2.000000e+00  3.385422e+01 -1.182076e+02  3.385420e+01 -1.182077e+02
# 50%    2.000000e+00  3.735113e+01 -9.438100e+01  3.735134e+01 -9.437987e+01
# 75%    2.000000e+00  4.072593e+01 -8.087469e+01  4.072593e+01 -8.087449e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  1.516064e+06  4.699690e+05    1.473031e+06   1.066748e+06
# mean   5.872617e-01  8.907533e+03    5.958460e+01   5.510976e+01
# std    1.632659e+00  2.242190e+04    1.827316e+01   2.112735e+01
# ...

# %%
numerics =['int16','int32','int64','float16','float32','float64']
numeric_df = df.select_dtypes(include = numerics)
len(numeric_df.columns)
# Out:
# 14

# %%
# percentage of missing values per columns
df.isna().sum().sort_values()
# Out:
# ID                             0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Country                        0
# Turning_Loop                   0
# State                          0
# County                         0
# Side                           0
# Street                         0
# Description                    0
# Distance(mi)                   0
# End_Lng                        0
# End_Lat                        0
# Start_Lng                      0
# Start_Lat                      0
# End_Time                       0
# Start_Time                     0
# Severity                       0
# Bump                           0
# Amenity                        0
# ...

# %%
missing_per = df.isna().sum().sort_values(ascending = False)/len(df)
missing_per
# Out:
# Number                   0.690007
# Precipitation(in)        0.336760
# Wind_Chill(F)            0.296370
# Wind_Speed(mph)          0.084998
# Humidity(%)              0.030018
# Visibility(mi)           0.029162
# Weather_Condition        0.029027
# Temperature(F)           0.028385
# Wind_Direction           0.027610
# Pressure(in)             0.023926
# Weather_Timestamp        0.019962
# Airport_Code             0.002802
# Timezone                 0.001518
# Zipcode                  0.000617
# Sunrise_Sunset           0.000055
# Civil_Twilight           0.000055
# Nautical_Twilight        0.000055
# Astronomical_Twilight    0.000055
# City                     0.000055
# Country                  0.000000
# Give_Way                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Turning_Loop             0.000000
# Traffic_Signal           0.000000
# Traffic_Calming          0.000000
# ...

# %%
type(missing_per)
# Out:
# pandas.core.series.Series

# %%
missing_per.plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
# to remove Zeros and remaining will show

missing_per != 0
# Out:
# Number                    True
# Precipitation(in)         True
# Wind_Chill(F)             True
# Wind_Speed(mph)           True
# Humidity(%)               True
# Visibility(mi)            True
# Weather_Condition         True
# Temperature(F)            True
# Wind_Direction            True
# Pressure(in)              True
# Weather_Timestamp         True
# Airport_Code              True
# Timezone                  True
# Zipcode                   True
# Sunrise_Sunset            True
# Civil_Twilight            True
# Nautical_Twilight         True
# Astronomical_Twilight     True
# City                      True
# Country                  False
# Give_Way                 False
# Start_Time               False
# End_Time                 False
# Start_Lat                False
# Turning_Loop             False
# Traffic_Signal           False
# Traffic_Calming          False
# Stop                     False
# Station                  False
# Roundabout               False
# ...

# %%
missing_per[missing_per != 0]
# Out:
# Number                   0.690007
# Precipitation(in)        0.336760
# Wind_Chill(F)            0.296370
# Wind_Speed(mph)          0.084998
# Humidity(%)              0.030018
# Visibility(mi)           0.029162
# Weather_Condition        0.029027
# Temperature(F)           0.028385
# Wind_Direction           0.027610
# Pressure(in)             0.023926
# Weather_Timestamp        0.019962
# Airport_Code             0.002802
# Timezone                 0.001518
# Zipcode                  0.000617
# Sunrise_Sunset           0.000055
# Civil_Twilight           0.000055
# Nautical_Twilight        0.000055
# Astronomical_Twilight    0.000055
# City                     0.000055
# dtype: float64

# %%
missing_per[missing_per != 0].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
# removes columns thats you don't want to use
## columns we'll analyze:
# '''
# 1.city
# 2.start time
# 3.start lat , start lng
# 4.temperature
# 5. weather condition
# '''

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
cities = df.City.unique()
print(len(cities))
cities[:100]
# Out:
# 10658
# array(['Dublin', 'Dayton', 'Cincinnati', 'Akron', 'Williamsburg',
#        'Batavia', 'Cleveland', 'Lima', 'Westerville', 'Jamestown',
#        'Freeport', 'Columbus', 'Toledo', 'Roanoke', 'Ft Mitchell',
#        'Edinburgh', 'Fairborn', 'Shelbyville', 'Greensburg', 'Saint Paul',
#        'Parkersburg', 'Indianapolis', 'Dundee', 'Jeffersonville',
#        'Pittsburgh', 'Lewis Center', 'Dunkirk', 'Redkey', 'Milton',
#        'Willshire', 'Straughn', 'Cambridge Springs', 'Fremont',
#        'Louisville', 'South Charleston', 'Edinboro', 'Buckhannon',
#        'Lockbourne', 'Painesville', 'Washington', 'Dunbar', 'Angola',
#        'Edon', 'Medina', 'De Mossville', 'New Albany', 'Charleston',
#        'Fort Wayne', 'Burnsville', 'Bedford', 'Clarksville', 'Lakewood',
#        'Richfield', 'Sewickley', 'Independence', 'Westlake', 'Erlanger',
#        'Grove City', 'Monroe', 'West Middlesex', 'Gaston', 'Economy',
# ...

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# Los Angeles     39984
# Miami           36233
# Charlotte       22203
# Houston         20843
# Dallas          19497
#                 ...
# Okaton              1
# Whigham             1
# Midwest City        1
# Bosque              1
# Brierfield          1
# Name: City, Length: 10657, dtype: int64

# %%
cities_by_accident[:10]
# Out:
# Los Angeles    39984
# Miami          36233
# Charlotte      22203
# Houston        20843
# Dallas         19497
# Sacramento     18431
# Orlando        16169
# Portland       14805
# San Diego      14090
# Minneapolis    12653
# Name: City, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# Los Angeles     39984
# Miami           36233
# Charlotte       22203
# Houston         20843
# Dallas          19497
# Sacramento      18431
# Orlando         16169
# Portland        14805
# San Diego       14090
# Minneapolis     12653
# Atlanta         11854
# Chicago         11507
# Saint Paul      10084
# Phoenix          9934
# Raleigh          9516
# San Jose         9362
# Richmond         8472
# Nashville        8381
# Riverside        8201
# Jacksonville     7815
# Name: City, dtype: int64

# %%
cities_by_accident[:20].plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.set_style("darkgrid")

# %%
sns.distplot(cities_by_accident)
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
sns.histplot(cities_by_accident , log_scale=True)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# Tate                  1
# Lenoxville            1
# Park Forest           1
# Fort Knox             1
# Niagara University    1
#                      ..
# Okaton                1
# Whigham               1
# Midwest City          1
# Bosque                1
# Brierfield            1
# Name: City, Length: 1167, dtype: int64

# %%
high_accident_cities = cities_by_accident[cities_by_accident>=1000]
low_accident_cities = cities_by_accident[cities_by_accident < 1000]

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.023550384687558643

# %%
sns.distplot(high_accident_cities)
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
sns.distplot(low_accident_cities)
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
### start time

# %%
df.Start_Time
# Out:
# 0          2016-02-08 00:37:08
# 1          2016-02-08 05:56:20
# 2          2016-02-08 06:15:39
# 3          2016-02-08 06:15:39
# 4          2016-02-08 06:51:45
#                   ...
# 1516059    2019-08-23 18:03:25
# 1516060    2019-08-23 19:11:30
# 1516061    2019-08-23 19:00:21
# 1516062    2019-08-23 19:00:21
# 1516063    2019-08-23 18:52:06
# Name: Start_Time, Length: 1516064, dtype: object

# %%
df.Start_Time[0]
# Out:
# '2016-02-08 00:37:08'

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 00:37:08')

# %%
sns.distplot(df.Start_Time.dt.hour ,bins = 24 ,kde= False ,norm_hist = True)
# A high perctange of Accident Occurs between 11am to 4 pm 
# for hours
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
sns.distplot(df.Start_Time.dt.dayofweek ,bins = 7 ,kde= False ,norm_hist = True)
# for weeks
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
sundays_Start_Time = df.Start_Time[df.Start_Time.dt.dayofweek == 6 ]

# %%
sns.distplot(sundays_Start_Time.dt.hour  ,bins = 24 ,kde= False ,norm_hist = True)
# sunday accidents graphs
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
mondays_Start_Time = df.Start_Time[df.Start_Time.dt.dayofweek == 0 ]
sns.distplot(mondays_Start_Time.dt.hour  ,bins = 24 ,kde= False ,norm_hist = True)
# monday accidents graphs
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# months accidents graphs
sns.distplot(mondays_Start_Time.dt.month  ,bins = 12 ,kde= False ,norm_hist = True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
df.Start_Time.dt.year
# Out:
# 0          2016
# 1          2016
# 2          2016
# 3          2016
# 4          2016
#            ...
# 1516059    2019
# 1516060    2019
# 1516061    2019
# 1516062    2019
# 1516063    2019
# Name: Start_Time, Length: 1516064, dtype: int64

# %%
# 2016 graph of accidenit
df_2016 = df[df.Start_Time.dt.year ==2016]
sns.distplot(df_2016.Start_Time.dt.month  ,bins = 12 ,kde= False ,norm_hist = True)
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# 2018 graph of accidenit
df_2018 = df[df.Start_Time.dt.year ==2018]
sns.distplot(df_2018.Start_Time.dt.month  ,bins = 12 ,kde= False ,norm_hist = True)
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# 2017 graph of accidenit
df_2017 = df[df.Start_Time.dt.year ==2017]
sns.distplot(df_2017.Start_Time.dt.month  ,bins = 12 ,kde= False ,norm_hist = True)
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# 2019 graph of accidenit
df_2019 = df[df.Start_Time.dt.year ==2019]
sns.distplot(df_2019.Start_Time.dt.month  ,bins = 12 ,kde= False ,norm_hist = True)
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
# 2020 graph of accidenit
df_2020 = df[df.Start_Time.dt.year ==2020]
sns.distplot(df_2020.Start_Time.dt.month  ,bins = 12 ,kde= False ,norm_hist = True)
# Out:
# C:\Jupiteraccs\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
#plotting the Lat against Long could show the map of the area
plt.figure(figsize=(50,30))
plt.title('Most Hits per Area')
plt.xlabel('Start Longitude')
plt.ylabel('Start Latitude')
plt.plot(df.Start_Lng, df.Start_Lat, ".", alpha=0.5, ms=1)
plt.show()

# %% [markdown]
# # Analyse Accident Number due to Weather Direction

# %%
Result6 = df.groupby('Wind_Direction').count()
Result6
# Out:
#                     ID  Severity  Start_Time  End_Time  Start_Lat  Start_Lng  \
# Wind_Direction
# CALM            202870    202870      202870    202870     202870     202870
# Calm             79192     79192       79192     79192      79192      79192
# E                52435     52435       52435     52435      52435      52435
# ENE              51257     51257       51257     51257      51257      51257
# ESE              51295     51295       51295     51295      51295      51295
# East             24064     24064       24064     24064      24064      24064
# N                53718     53718       53718     53718      53718      53718
# NE               48355     48355       48355     48355      48355      48355
# NNE              46509     46509       46509     46509      46509      46509
# NNW              68014     68014       68014     68014      68014      68014
# NW               75810     75810       75810     75810      75810      75810
# ...

# %%
plt.figure(figsize=(30, 10))
plt.title('Number of Accidents due to Wind_Directions')
plt.bar(Result6.index, Result6.Number, color='r')
plt.xlabel('Wind_Directions')
plt.ylabel('Number of Accidents')
plt.xticks(Result6.index, rotation='vertical', size=15)
plt.show()

# %% [markdown]
# # Distribution of Latitudes and Longitudes

# %%
plt.hist(df.Start_Lng, bins=31, range=(-110, -65))
plt.show()

# %%
plt.hist(df.End_Lng,bins=31)
plt.show()

# %%
plt.hist(df.Start_Lat, bins=31, range=(26, 49))
plt.show()

# %%
plt.hist(df.End_Lat, bins=31)
plt.show()

# %%
sns.scatterplot(x = df.Start_Lng , y = df.Start_Lat)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
import matplotlib.pyplot as plt 
# plot a histogram  
df['Severity'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(20,5))
df.groupby(['State' ])['Severity'].sum().sort_values(ascending=False).head(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='State'>

# %%
#Which State has highest accident cases is seen abov
plt.figure(figsize =(10,5))
df.groupby(['Sunrise_Sunset'])['Severity'].size().sort_values(ascending=False).plot.pie()
# Out:
# <AxesSubplot:ylabel='Severity'>

# %%
#When do accidents happen the most ? they happen when the Stop sign, Station signs & railway crossings are not followed
plt.figure(figsize =(10,5))
df.groupby(['Give_Way', 'Crossing','Bump' ])['Severity'].sum().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Give_Way,Crossing,Bump'>

# %%
#How was the weather conditions during the accidents? Mostly clear...

plt.figure(figsize =(12,5))
df.groupby(['Visibility(mi)']).size().sort_values(ascending=False).head(12).plot.bar()
# Out:
# <AxesSubplot:xlabel='Visibility(mi)'>

# %% [markdown]
# # Done :-  PIYUSH SAINI
